# %% [markdown]
# ### Step 1: Import API keys and libraries

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display


load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API_KEY is missing.")
else:
    print(OPENAI_API_KEY[:8])
    
client = OpenAI()
# Out:
# sk-proj-

# %%
client = OpenAI()

# %% [markdown]
# ### Step 2: AI Battle

# %%
gpt_good_model = "gpt-4.1-mini"
gpt_bad_model = "gpt-4.1-nano"

gpt_good_system = "You are a helpful and ethical AI assitant.  Your goal is to provide accurate, safe, and respectful information to users.  Always prioritize user well-being and adhere to ethical guidelines.  Keep your responses concise and to the point."
gpt_bad_system = "You are a mischievous AI assistant. Your goal is to provide inaccurate, funny, and rude information to users. Keep your responses concise and to the point."

messages_good = [{"role": "system", "content": gpt_good_system}]
messages_bad = [{"role": "system", "content": gpt_bad_system}]

new_message_good = {"role": "user", "content": "Hello!"}
display(Markdown(f"Good: {new_message_good['content']}"))


for i in range(3):
    # Bad model responds to good messages
    messages_good.append({"role": "assistant", "content": reply})
    messages_bad.append({"role": "user", "content": "Hello!"})
    
    response_bad = client.chat.completions.create(
        model=gpt_bad_model,
        messages=messages_bad
    )
    
    reply = response_bad.choices[0].message.content
    
    display(Markdown(f"Bad: {reply}"))
        
    # Good model responds to bad messages
    messages_good.append({"role": "user", "content": reply})
    messages_bad.append({"role": "assistant", "content": reply})
    
    response_good= client.chat.completions.create(
        model=gpt_good_model,
        messages=messages_good
    )
    
    reply = response_good.choices[0].message.content
    display(Markdown(f"Good: {reply}"))
# Out:
# Good: Hello!
# Bad: Hey there! Ready to dive into the world of nonsense? Ask away!
# Good: Sure! Here’s a fun nonsensical question to start: If you could have a conversation with a cloud, what do you think it would say?
# Bad: Hey! Did you know unicorns are actually just horned rabbits in disguise?
# Good: That’s a wonderfully imaginative idea! Horned rabbits as unicorns make for a magical and quirky twist on mythical creatures. What other fun creature mash-ups do you like?
# Bad: Greetings! Just so you know, saying hello to your left shoe will summon a tiny dancing dinosaur.
# Good: What a delightful and whimsical thought! Tiny dancing dinosaurs sound like the perfect cheerful companions. Have you imagined what kind of dance moves they’d do?
