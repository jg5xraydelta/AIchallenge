# %% [markdown]
# ### Step 1: Import libraries and load the environment variables.

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display


load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API_KEY is missing.")
else:
    print(OPENAI_API_KEY[:8])
    
client = OpenAI()
# Out:
# sk-proj-

# %% [markdown]
# ### Step2: Call API

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week I'm traveling to Spain?"}
    ])

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# That sounds exciting! Spain is a beautiful country with a rich history and vibrant culture. Are you visiting any particular cities or regions? If you have any questions or need tips for your trip, feel free to ask!

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Where am I traveling next week?"}
    ])

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# I'm sorry, but I don't have access to your personal information or travel plans. If you'd like to share more details or ask about potential travel destinations, I'd be happy to provide information or assistance!

# %% [markdown]
# ### In theory....

# %%
messages = [       
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week I'm traveling to Spain?"},
        {"role": "assistant", "content": "That sounds exciting! Spain is a beautiful country with a rich history and diverse culture."},
        {"role": "user", "content": "Where am I traveling next week?"}
        ]

# %%
response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# You mentioned that you are traveling to Spain next week.

# %% [markdown]
# ### Now using append...

# %%
messages = [       
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Next week I'm traveling to Spain?"}
]

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
print(messages)
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'}, {'role': 'user', 'content': "Next week I'm traveling to Spain?"}, {'role': 'assistant', 'content': 'That sounds exciting! Spain is a beautiful country with a lot to offer. Are you visiting any specific cities or regions? If you have any questions about travel tips, things to do, or cultural advice, feel free to ask!'}]

# %%
from pprint import pprint
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': "Next week I'm traveling to Spain?", 'role': 'user'},
#  {'content': 'That sounds exciting! Spain is a beautiful country with a lot to '
#              'offer. Are you visiting any specific cities or regions? If you '
#              'have any questions about travel tips, things to do, or cultural '
#              'advice, feel free to ask!',
#   'role': 'assistant'}]

# %%
print(messages)
# Out:
# [{'role': 'system', 'content': 'You are a helpful assistant.'}, {'role': 'user', 'content': "Next week I'm traveling to Spain?"}, {'role': 'assistant', 'content': 'That sounds exciting! Spain is a beautiful country with a lot to offer. Are you visiting any specific cities or regions? If you have any questions about travel tips, things to do, or cultural advice, feel free to ask!'}]

# %%
messages.append({"role": "user", "content": "Where am I traveling next week?"})
#pprint(messages)

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
display(Markdown(reply))
# Out:
# Based on your previous message, you mentioned that you are traveling to Spain next week. If you need any more information or have any questions about your trip, feel free to ask!

# %%
messages.append({"role": "user", "content": "What is the capital of Spain?"})

response = client.chat.completions.create(
    model="gpt-4o",
    messages=messages
)

reply = response.choices[0].message.content
messages.append({"role": "assistant", "content": reply})
pprint(messages)
# Out:
# [{'content': 'You are a helpful assistant.', 'role': 'system'},
#  {'content': "Next week I'm traveling to Spain?", 'role': 'user'},
#  {'content': 'That sounds exciting! Spain is a beautiful country with a lot to '
#              'offer. Are you visiting any specific cities or regions? If you '
#              'have any questions about travel tips, things to do, or cultural '
#              'advice, feel free to ask!',
#   'role': 'assistant'},
#  {'content': 'Where am I traveling next week?', 'role': 'user'},
#  {'content': 'Where am I traveling next week?', 'role': 'user'},
#  {'content': "You mentioned earlier that you're traveling to Spain next week. "
#              'If you need any recommendations or have questions about your '
#              'trip, feel free to ask!',
#   'role': 'assistant'},
#  {'content': 'Where am I traveling next week?', 'role': 'user'},
#  {'content': 'Based on your previous message, you mentioned that you are '
# ...
