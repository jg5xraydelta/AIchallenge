# %% [markdown]
# ### Step 1: Import Libraries and load the environment variables

# %%
import os
from openai import OpenAI
from dotenv import load_dotenv

# %%
load_dotenv()

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")

if OPENAI_API_KEY is None:
    raise Exception("API_KEY is missing.")
else:
    print(OPENAI_API_KEY[:8])
# Out:
# sk-proj-

# %% [markdown]
# ### Step 2: Call the API

# %%
client = OpenAI()

response = client.chat.completions.create(
    model="gpt-4.1-mini",
    messages=[{"role":"user", "content":"Show me a picture of an okapi."}]
)

answer = response.choices[0].message.content

print(answer)
# Out:
# I can't show images directly, but I can describe the okapi for you! The okapi is a mammal native to the rainforests of the Democratic Republic of Congo in Central Africa. It has a body shape similar to a giraffe but is much shorter. Its coat is chocolate to reddish-brown, and its legs have striking white and black horizontal stripes, which look somewhat like zebra stripes. If you'd like, I can also help you find a link to images of an okapi online! Would you like that?
